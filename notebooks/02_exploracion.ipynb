# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import statsmodels as sm

# %%
df = pd.read_csv('/Users/servandolopez/Documents/Proyectos/climatesim/data/processed/processed_data.csv')
df.info()
df.describe()
df['PRECIP'].plot(figsize=(15, 2))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1877 entries, 0 to 1876
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PRECIP  1877 non-null   float64
#  1   EVAP    1877 non-null   float64
#  2   TMAX    1877 non-null   float64
#  3   TMIN    1877 non-null   float64
# dtypes: float64(4)
# memory usage: 58.8 KB
# <Axes: >

# %%
df.describe()
# Out:
#             PRECIP         EVAP         TMAX         TMIN
# count  1877.000000  1877.000000  1877.000000  1877.000000
# mean      0.081789     0.424136     0.619883     0.560073
# std       0.114148     0.141280     0.182090     0.144334
# min       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     0.321818     0.513274     0.456897
# 50%       0.033953     0.418182     0.654867     0.543103
# 75%       0.123256     0.520000     0.756637     0.655172
# max       1.000000     1.000000     1.000000     1.000000
